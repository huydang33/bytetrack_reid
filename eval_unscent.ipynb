# %%
# !python3 tools/track.py -f exps/example/mot/yolox_x_ablation.py -c YOLOX_outputs/yolox_x_ablation/best_ckpt.pth.tar -b 1 -d 1 --fp16 --fuse
# Out:
# 2024-05-02 14:52:41 | INFO     | __main__:154 - Args: Namespace(experiment_name='yolox_x_ablation', name=None, dist_backend='nccl', dist_url=None, batch_size=1, devices=1, local_rank=0, num_machines=1, machine_rank=0, exp_file='exps/example/mot/yolox_x_ablation.py', fp16=True, fuse=True, trt=False, test=False, speed=False, opts=[], ckpt='YOLOX_outputs/yolox_x_ablation/best_ckpt.pth.tar', conf=0.01, nms=0.7, tsize=None, seed=None, track_thresh=0.6, track_buffer=30, match_thresh=0.9, min_box_area=100, mot20=False)
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 2024-05-02 14:52:41 | INFO     | __main__:164 - Model Summary: Params: 99.00M, Gflops: 793.21
# 2024-05-02 14:52:41 | INFO     | yolox.data.datasets.mot:39 - loading annotations into memory...
# 2024-05-02 14:52:41 | INFO     | yolox.data.datasets.mot:39 - Done (t=0.17s)
# 2024-05-02 14:52:41 | INFO     | pycocotools.coco:88 - creating index...
# 2024-05-02 14:52:41 | INFO     | pycocotools.coco:88 - index created!
# 2024-05-02 14:52:42 | INFO     | __main__:186 - loading checkpoint
# 2024-05-02 14:52:44 | INFO     | __main__:191 - loaded checkpoint done.
# 2024-05-02 14:52:44 | INFO     | __main__:197 - 	Fusing model...
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:844: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at aten/src/ATen/core/TensorBody.h:489.)
#   if param.grad is not None:
#   0%|          | 1/2652 [00:01<1:06:21,  1.50s/it](17, 8)
#   0%|          | 1/2652 [00:01<1:10:16,  1.59s/it]
# 2024-05-02 14:52:46 | ERROR    | yolox.core.launch:90 - An error has been caught in function 'launch', process 'MainProcess' (203774), thread 'MainThread' (139782212444160):
# Traceback (most recent call last):
#
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/tools/track.py", line 285, in <module>
#     launch(
#     └ <function launch at 0x7f20d65ee320>
#
# > File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/yolox/core/launch.py", line 90, in launch
#     main_func(*args)
#     │          └ (╒══════════════════╤══════════════════════════════════════════════════════════════════════════════════════════════╕
#     │            │ keys  ...
#     └ <function main at 0x7f20ad303d90>
#
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/tools/track.py", line 215, in main
#     *_, summary = evaluator.evaluate(
#                   │         └ <function MOTEvaluator.evaluate at 0x7f20af71b5b0>
#                   └ <yolox.evaluators.mot_evaluator.MOTEvaluator object at 0x7f2093278040>
#
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/yolox/evaluators/mot_evaluator.py", line 190, in evaluate
#     online_targets = tracker.update(outputs[0], info_imgs, self.img_size)
#                      │       │      │           │          │    └ (800, 1440)
#                      │       │      │           │          └ <yolox.evaluators.mot_evaluator.MOTEvaluator object at 0x7f2093278040>
#                      │       │      │           └ [tensor([1080]), tensor([1920]), tensor([2]), tensor([1]), ['MOT17-02-FRCNN/img1/000303.jpg']]
#                      │       │      └ [tensor([[ 3.7400e+02,  3.3725e+02,  4.0200e+02,  4.1625e+02,  9.9756e-01,
#                      │       │                  9.3018e-01,  0.0000e+00],
#                      │       │                [ 5.70...
#                      │       └ <function BYTETracker.update at 0x7f20af6f5cf0>
#                      └ <yolox.tracker.byte_tracker.BYTETracker object at 0x7f20ab121120>
#
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/yolox/tracker/byte_tracker.py", line 213, in update
#     STrack.multi_predict(strack_pool)
#     │      │             └ [OT_1_(1-1), OT_2_(1-1), OT_3_(1-1), OT_4_(1-1), OT_5_(1-1), OT_6_(1-1), OT_7_(1-1), OT_8_(1-1), OT_9_(1-1), OT_10_(1-1), OT_...
#     │      └ <staticmethod(<function STrack.multi_predict at 0x7f20af6f5630>)>
#     └ <class 'yolox.tracker.byte_tracker.STrack'>
#
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/yolox/tracker/byte_tracker.py", line 45, in multi_predict
#     multi_mean[i], multi_covariance[i] = STrack.shared_kalman.predict(multi_mean[i], multi_covariance[i])
#     │          │   │                │    │      │             │       │          │   │                └ 0
#     │          │   │                │    │      │             │       │          │   └ array([[[1.12307084e+02, 0.00000000e+00, 0.00000000e+00, ...,
#     │          │   │                │    │      │             │       │          │              0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#     │          │   │                │    │      │             │       │          │          ...
#     │          │   │                │    │      │             │       │          └ 0
#     │          │   │                │    │      │             │       └ array([[5.24812515e+02, 5.08612518e+02, 3.56687948e-01, 1.05975037e+02,
#     │          │   │                │    │      │             │                 0.00000000e+00, 0.00000000e+00, 0.00000000e+0...
#     │          │   │                │    │      │             └ <function UnscentedKalmanFilter.predict at 0x7f20af6db5b0>
#     │          │   │                │    │      └ <yolox.tracker.unscented_kalman_filter.UnscentedKalmanFilter object at 0x7f20c5cb8be0>
#     │          │   │                │    └ <class 'yolox.tracker.byte_tracker.STrack'>
#     │          │   │                └ 0
#     │          │   └ array([[[1.12307084e+02, 0.00000000e+00, 0.00000000e+00, ...,
#     │          │              0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#     │          │          ...
#     │          └ 0
#     └ array([[5.24812515e+02, 5.08612518e+02, 3.56687948e-01, 1.05975037e+02,
#               0.00000000e+00, 0.00000000e+00, 0.00000000e+0...
#
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/yolox/tracker/unscented_kalman_filter.py", line 101, in predict
#     predicted_mean, predicted_cov = self.unscented_transform(
#                                     │    └ <function UnscentedKalmanFilter.unscented_transform at 0x7f20af6dbac0>
#                                     └ <yolox.tracker.unscented_kalman_filter.UnscentedKalmanFilter object at 0x7f20c5cb8be0>
#
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/yolox/tracker/unscented_kalman_filter.py", line 123, in unscented_transform
#     cov = np.dot(residual.T, Wc * residual)
#           │  │   │        │  │    └ array([[[-3.28002574e+07, -3.17877738e+07, -2.22926400e+04,
#           │  │   │        │  │               -6.62333381e+06,  0.00000000e+00,  0.00000000e+00,
#           │  │   │        │  │           ...
#           │  │   │        │  └ 62499.99999820277
#           │  │   │        └ <attribute 'T' of 'numpy.ndarray' objects>
#           │  │   └ array([[[-3.28002574e+07, -3.17877738e+07, -2.22926400e+04,
#           │  │              -6.62333381e+06,  0.00000000e+00,  0.00000000e+00,
#           │  │          ...
#           │  └ <function dot at 0x7f2186b3ed30>
#           └ <module 'numpy' from '/home/huythanhdang/.local/lib/python3.10/site-packages/numpy/__init__.py'>
#
# ValueError: shapes (8,17,1) and (1,17,8) not aligned: 1 (dim 2) != 17 (dim 1)
