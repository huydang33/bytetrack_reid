| INFO     | yolox.evaluators.mot_evaluator:630 - Evaluate in main process...
# 2024-05-19 13:20:21 | INFO     | yolox.evaluators.mot_evaluator:659 - Loading and preparing results...
# 2024-05-19 13:20:24 | INFO     | yolox.evaluators.mot_evaluator:659 - DONE (t=2.84s)
# 2024-05-19 13:20:24 | INFO     | pycocotools.coco:363 - creating index...
# 2024-05-19 13:20:24 | INFO     | pycocotools.coco:363 - index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 4.22 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 1.94 seconds.
# 2024-05-19 13:20:31 | INFO     | __main__:230 -
# Average forward time: 68.78 ms, Average track time: 307.29 ms, Average inference time: 376.07 ms
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#
# gt_type
# gt_files ['datasets/mot/train/MOT17-02-DPM/gt/gt.txt', 'datasets/mot/train/MOT17-02-FRCNN/gt/gt.txt', 'datasets/mot/train/MOT17-02-SDP/gt/gt.txt', 'datasets/mot/train/MOT17-04-DPM/gt/gt.txt', 'datasets/mot/train/MOT17-04-FRCNN/gt/gt.txt', 'datasets/mot/train/MOT17-04-SDP/gt/gt.txt', 'datasets/mot/train/MOT17-05-DPM/gt/gt.txt', 'datasets/mot/train/MOT17-05-FRCNN/gt/gt.txt', 'datasets/mot/train/MOT17-05-SDP/gt/gt.txt', 'datasets/mot/train/MOT17-09-DPM/gt/gt.txt', 'datasets/mot/train/MOT17-09-FRCNN/gt/gt.txt', 'datasets/mot/train/MOT17-09-SDP/gt/gt.txt', 'datasets/mot/train/MOT17-10-DPM/gt/gt.txt', 'datasets/mot/train/MOT17-10-FRCNN/gt/gt.txt', 'datasets/mot/train/MOT17-10-SDP/gt/gt.txt', 'datasets/mot/train/MOT17-11-DPM/gt/gt.txt', 'datasets/mot/train/MOT17-11-FRCNN/gt/gt.txt', 'datasets/mot/train/MOT17-11-SDP/gt/gt.txt', 'datasets/mot/train/MOT17-13-DPM/gt/gt.txt', 'datasets/mot/train/MOT17-13-FRCNN/gt/gt.txt', 'datasets/mot/train/MOT17-13-SDP/gt/gt.txt']
# 2024-05-19 13:20:31 | INFO     | __main__:247 - Found 21 groundtruths and 21 test files.
# 2024-05-19 13:20:31 | INFO     | __main__:248 - Available LAP solvers ['lap', 'scipy']
# 2024-05-19 13:20:31 | INFO     | __main__:249 - Default LAP solver 'lap'
# 2024-05-19 13:20:31 | INFO     | __main__:250 - Loading files.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-01-DPM, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-01-FRCNN, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-01-SDP, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-03-DPM, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-03-FRCNN, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-03-SDP, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-06-DPM, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-06-FRCNN, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-06-SDP, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-07-DPM, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-07-FRCNN, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-07-SDP, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-08-DPM, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-08-FRCNN, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-08-SDP, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-12-DPM, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-12-FRCNN, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-12-SDP, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-14-DPM, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-14-FRCNN, skipping.
# 2024-05-19 13:20:38 | WARNING  | __main__:130 - No ground truth for MOT17-14-SDP, skipping.
# 2024-05-19 13:20:38 | INFO     | __main__:258 - Running metrics
#         Rcll Prcn GT  MT  PT  ML  FP  FN IDs  FM MOTA MOTP num_objects
# OVERALL  NaN  NaN  0 NaN NaN NaN NaN NaN NaN NaN  NaN  NaN           0
#         IDF1 IDP IDR Rcll Prcn GT MT PT ML FP FN IDs  FM MOTA MOTP IDt IDa IDm num_objects
# OVERALL  NaN NaN NaN  NaN  NaN  0  0  0  0  0  0   0   0  NaN  NaN   0   0   0           0
# 2024-05-19 13:20:38 | INFO     | __main__:283 - Completed

# %%
# !python3 tools/interpolation.py
# Out:
# Before DTI:
#                IDF1  IDP IDR Rcll Prcn GT MT PT ML     FP FN IDs  FM  MOTA MOTP IDt IDa IDm
# MOT17-01-FRCNN 0.0% 0.0% NaN  NaN 0.0%  0  0  0  0   5702  0   0   0 -inf%  NaN   0   0   0
# MOT17-03-FRCNN 0.0% 0.0% NaN  NaN 0.0%  0  0  0  0 104323  0   0   0 -inf%  NaN   0   0   0
# MOT17-06-FRCNN 0.0% 0.0% NaN  NaN 0.0%  0  0  0  0   8748  0   0   0 -inf%  NaN   0   0   0
# MOT17-07-FRCNN 0.0% 0.0% NaN  NaN 0.0%  0  0  0  0  14562  0   0   0 -inf%  NaN   0   0   0
# MOT17-08-FRCNN 0.0% 0.0% NaN  NaN 0.0%  0  0  0  0  17320  0   0   0 -inf%  NaN   0   0   0
# MOT17-12-FRCNN 0.0% 0.0% NaN  NaN 0.0%  0  0  0  0   6851  0   0   0 -inf%  NaN   0   0   0
# MOT17-14-FRCNN 0.0% 0.0% NaN  NaN 0.0%  0  0  0  0  10051  0   0   0 -inf%  NaN   0   0   0
# OVERALL        0.0% 0.0% NaN  NaN 0.0%  0  0  0  0 167557  0   0   0 -inf%  NaN   0   0   0
# After DTI:
#                IDF1  IDP IDR Rcll Prcn GT MT PT ML     FP FN IDs  FM  MOTA MOTP IDt IDa IDm
# MOT17-01-FRCNN 0.0% 0.0% NaN  NaN 0.0%  0  0  0  0   6122  0   0   0 -inf%  NaN   0   0   0
# MOT17-03-FRCNN 0.0% 0.0% NaN  NaN 0.0%  0  0  0  0 105392  0   0   0 -inf%  NaN   0   0   0
# MOT17-06-FRCNN 0.0% 0.0% NaN  NaN 0.0%  0  0  0  0   9749  0   0   0 -inf%  NaN   0   0   0
# MOT17-07-FRCNN 0.0% 0.0% NaN  NaN 0.0%  0  0  0  0  15042  0   0   0 -inf%  NaN   0   0   0
# MOT17-08-FRCNN 0.0% 0.0% NaN  NaN 0.0%  0  0  0  0  18876  0   0   0 -inf%  NaN   0   0   0
# MOT17-12-FRCNN 0.0% 0.0% NaN  NaN 0.0%  0  0  0  0   7103  0   0   0 -inf%  NaN   0   0   0
# MOT17-14-FRCNN 0.0% 0.0% NaN  NaN 0.0%  0  0  0  0  10718  0   0   0 -inf%  NaN   0   0   0
# OVERALL        0.0% 0.0% NaN  NaN 0.0%  0  0  0  0 173002  0   0   0 -inf%  NaN   0   0   0

# %%
# !python3 tools/track.py \
        -f exps/example/mot/yolox_x_mix_det.py \
        -c pretrained/bytetrack_x_mot17.pth.tar \
        -b 1 -d 1 --fp16 --fuse \
        --feat_model_name fastreid \
        --feat_args_cfg "pretrained/fastreid_market1501_bagtrickR50/config.yaml" \
        --feat_model_weights "pretrained/fastreid_market1501_bagtrickR50/model_final.pth" \
        --fusion_type "average"
# Out:
# 2024-05-19 11:07:06 | INFO     | __main__:162 - Args: Namespace(experiment_name='yolox_x_mix_det', name=None, dist_backend='nccl', dist_url=None, batch_size=1, devices=1, local_rank=0, num_machines=1, machine_rank=0, exp_file='exps/example/mot/yolox_x_mix_det.py', fp16=True, fuse=True, trt=False, test=False, speed=False, opts=[], ckpt='pretrained/bytetrack_x_mot17.pth.tar', conf=0.01, nms=0.7, tsize=None, seed=None, track_thresh=0.6, track_buffer=30, match_thresh=0.9, min_box_area=100, mot20=False, feat_model_name='fastreid', feat_args_cfg='pretrained/fastreid_market1501_bagtrickR50/config.yaml', feat_model_weights='pretrained/fastreid_market1501_bagtrickR50/model_final.pth', reid_weight=0.1, fusion_type='average')
# /home/huythanhdang/.local/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 2024-05-19 11:07:08 | INFO     | __main__:172 - Model Summary: Params: 99.00M, Gflops: 793.21
# 2024-05-19 11:07:11 | INFO     | yolox.data.datasets.mot:39 - loading annotations into memory...
# 2024-05-19 11:07:11 | INFO     | yolox.data.datasets.mot:39 - Done (t=0.03s)
# 2024-05-19 11:07:11 | INFO     | pycocotools.coco:88 - creating index...
# 2024-05-19 11:07:11 | INFO     | pycocotools.coco:88 - index created!
# 2024-05-19 11:07:12 | INFO     | __main__:198 - loading checkpoint
# 2024-05-19 11:07:15 | INFO     | __main__:203 - loaded checkpoint done.
# 2024-05-19 11:07:15 | INFO     | __main__:209 - 	Fusing model...
# /home/huythanhdang/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:675: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at aten/src/ATen/core/TensorBody.h:480.)
#   if param.grad is not None:
#   3%|2         | 450/17757 [02:08<1:17:18,  3.73it/s]2024-05-19 11:09:26 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-01-DPM.txt
#   5%|5         | 900/17757 [04:12<1:16:45,  3.66it/s]2024-05-19 11:11:29 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-01-FRCNN.txt
#   8%|7         | 1350/17757 [06:16<1:13:36,  3.72it/s]2024-05-19 11:13:33 | INFO     | yolox.evaluators.mot_evaluator:39 - save results to ./YOLOX_outputs/yolox_x_mix_det/track_results/MOT17-01-SDP.txt
#  15%|#5        | 2748/17757 [20:08<2:36:52,  1.59it/s]^C
#  15%|#5        | 2748/17757 [20:08<1:50:01,  2.27it/s]
# Traceback (most recent call last):
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/tools/track.py", line 297, in <module>
#     launch(
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/yolox/core/launch.py", line 90, in launch
#     main_func(*args)
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/loguru/_logger.py", line 1277, in catch_wrapper
#     return function(*args, **kwargs)
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/tools/track.py", line 227, in main
#     *_, summary = evaluator.evaluate(
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/yolox/evaluators/mot_evaluator.py", line 192, in evaluate
#     online_targets = tracker.update(outputs[0], info_imgs, self.img_size, imgs, self.feature_extract_model)
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/yolox/tracker/byte_tracker.py", line 321, in update
#     list_highscr_feat = self.get_feature_extracted(feature_extract_model, imgs, dets)
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/yolox/tracker/byte_tracker.py", line 262, in get_feature_extracted
#     features = model(final_tensor.float())  # Trích xuất đặc trưng
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1194, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/fastreid/modeling/meta_arch/baseline.py", line 101, in forward
#     features = self.backbone(images)
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1194, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/fastreid/modeling/backbones/resnet.py", line 212, in forward
#     x = self.layer3[i](x)
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1194, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/fastreid/modeling/backbones/resnet.py", line 106, in forward
#     out = self.conv1(x)
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1194, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py", line 463, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py", line 459, in _conv_forward
#     return F.conv2d(input, weight, bias, self.stride,
# KeyboardInterrupt

# %%
# !python3 tools/track.py \
        -f exps/example/mot/yolox_x_mix_det.py \
        -c pretrained/bytetrack_x_mot17.pth.tar \
        -b 1 -d 1 --fp16 --fuse \
        --feat_model_name fastreid \
        --feat_args_cfg "pretrained/fastreid_market1501_bagtrickR50/config.yaml" \
        --feat_model_weights "pretrained/fastreid_market1501_bagtrickR50/model_final.pth" \
        --fusion_type "median"
# Out:
# 2024-05-19 11:27:28 | INFO     | __main__:162 - Args: Namespace(experiment_name='yolox_x_mix_det', name=None, dist_backend='nccl', dist_url=None, batch_size=1, devices=1, local_rank=0, num_machines=1, machine_rank=0, exp_file='exps/example/mot/yolox_x_mix_det.py', fp16=True, fuse=True, trt=False, test=False, speed=False, opts=[], ckpt='pretrained/bytetrack_x_mot17.pth.tar', conf=0.01, nms=0.7, tsize=None, seed=None, track_thresh=0.6, track_buffer=30, match_thresh=0.9, min_box_area=100, mot20=False, feat_model_name='fastreid', feat_args_cfg='pretrained/fastreid_market1501_bagtrickR50/config.yaml', feat_model_weights='pretrained/fastreid_market1501_bagtrickR50/model_final.pth', reid_weight=0.1, fusion_type='median')
# /home/huythanhdang/.local/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 2024-05-19 11:27:29 | INFO     | __main__:172 - Model Summary: Params: 99.00M, Gflops: 793.21
# ^C
# Traceback (most recent call last):
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/tools/track.py", line 297, in <module>
#     launch(
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/yolox/core/launch.py", line 90, in launch
#     main_func(*args)
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/loguru/_logger.py", line 1277, in catch_wrapper
#     return function(*args, **kwargs)
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/tools/track.py", line 176, in main
#     feat_ext_model = build_feature_extract_model(args)
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/yolox/models/feature_extract_model.py", line 30, in build_feature_extract_model
#     model = build_model(cfg)
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/fastreid/modeling/meta_arch/build.py", line 24, in build_model
#     model = META_ARCH_REGISTRY.get(meta_arch)(cfg)
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/fastreid/config/config.py", line 244, in wrapped
#     explicit_args = _get_args_from_config(from_config_func, *args, **kwargs)
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/fastreid/config/config.py", line 300, in _get_args_from_config
#     ret = from_config_func(*args, **kwargs)
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/fastreid/modeling/meta_arch/baseline.py", line 58, in from_config
#     backbone = build_backbone(cfg)
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/fastreid/modeling/backbones/build.py", line 26, in build_backbone
#     backbone = BACKBONE_REGISTRY.get(backbone_name)(cfg)
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/fastreid/modeling/backbones/resnet.py", line 352, in build_resnet_backbone
#     state_dict = init_pretrained_weights(key)
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/fastreid/modeling/backbones/resnet.py", line 288, in init_pretrained_weights
#     state_dict = torch.load(cached_file, map_location=torch.device('cpu'))
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/torch/serialization.py", line 795, in load
#     return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/torch/serialization.py", line 987, in _legacy_load
#     return legacy_load(f)
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/torch/serialization.py", line 891, in legacy_load
#     obj = cast(Storage, torch.UntypedStorage)._new_with_file(f, torch._utils._element_size(dtype))
# KeyboardInterrupt

# %%
# !python3 tools/track.py \
        -f exps/example/mot/yolox_x_mix_det.py \
        -c pretrained/bytetrack_x_mot17.pth.tar \
        -b 1 -d 1 --fp16 --fuse \
        --feat_model_name fastreid \
        --feat_args_cfg "pretrained/fastreid_market1501_bagtrickR50/config.yaml" \
        --feat_model_weights "pretrained/fastreid_market1501_bagtrickR50/model_final.pth" \
        --fusion_type "fuzzy_weight"
# Out:
# ^C
# Traceback (most recent call last):
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/tools/track.py", line 10, in <module>
#     from yolox.evaluators import MOTEvaluator
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/yolox/evaluators/__init__.py", line 6, in <module>
#     from .mot_evaluator import MOTEvaluator
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/yolox/evaluators/mot_evaluator.py", line 16, in <module>
#     from yolox.sort_tracker.sort import Sort
#   File "/mnt/c/Users/NCPC/Desktop/thesis/ByteTrack/yolox/sort_tracker/sort.py", line 20, in <module>
#     from filterpy.kalman import KalmanFilter
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/filterpy/kalman/__init__.py", line 22, in <module>
#     from .EKF import *
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/filterpy/kalman/EKF.py", line 28, in <module>
#     from filterpy.stats import logpdf
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/filterpy/stats/__init__.py", line 22, in <module>
#     from .stats import *
#   File "/home/huythanhdang/.local/lib/python3.10/site-packages/filterpy/stats/stats.py", line 32, in <module>
#     from scipy.stats import norm, multivariate_normal
#   File "/usr/local/lib/python3.10/dist-packages/scipy/stats/__init__.py", line 605, in <module>
#     from ._stats_py import *
#   File "/usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py", line 45, in <module>
#     from . import distributions
#   File "/usr/local/lib/python3.10/dist-packages/scipy/stats/distributions.py", line 10, in <module>
#     from . import _continuous_distns
#   File "/usr/local/lib/python3.10/dist-packages/scipy/stats/_continuous_distns.py", line 3967, in <module>
#     gompertz = gompertz_gen(a=0.0, name='gompertz')
#   File "/usr/local/lib/python3.10/dist-packages/scipy/stats/_distn_infrastructure.py", line 1828, in __init__
#     self._construct_argparser(meths_to_inspect=[self._pdf, self._cdf],
#   File "/usr/local/lib/python3.10/dist-packages/scipy/stats/_distn_infrastructure.py", line 738, in _construct_argparser
#     shapes_args = _getfullargspec(meth)  # NB does not contain self
#   File "/usr/local/lib/python3.10/dist-packages/scipy/_lib/_util.py", line 383, in getfullargspec_no_self
#     sig = inspect.signature(func)
#   File "/usr/lib/python3.10/inspect.py", line 3254, in signature
#     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#   File "/usr/lib/python3.10/inspect.py", line 3002, in from_callable
#     return _signature_from_callable(obj, sigcls=cls,
#   File "/usr/lib/python3.10/inspect.py", line 2404, in _signature_from_callable
#     return _signature_bound_method(sig)
#   File "/usr/lib/python3.10/inspect.py", line 1982, in _signature_bound_method
#     return sig.replace(parameters=params)
#   File "/usr/lib/python3.10/inspect.py", line 3026, in replace
#     return type(self)(parameters,
# KeyboardInterrupt
