# %%
# !python3 tools/train.py -f exps/example/mot/yolox_x_ablation.py -d 1 -b 2 --fp16 -o -c ./pretrained/last_epoch_ckpt.pth.tar --early_stopping True
# Out:
# 2024-04-29 16:52:02 | INFO     | yolox.core.trainer:144 - args: Namespace(experiment_name='yolox_x_ablation', name=None, dist_backend='nccl', dist_url=None, batch_size=2, devices=1, local_rank=0, exp_file='exps/example/mot/yolox_x_ablation.py', resume=False, ckpt='./pretrained/last_epoch_ckpt.pth.tar', start_epoch=None, num_machines=1, machine_rank=0, fp16=True, occupy=True, opts=[], early_stopping=True)
# 2024-04-29 16:52:02 | INFO     | yolox.core.trainer:145 - exp value:
# ╒══════════════════╤════════════════════╕
# │ keys             │ values             │
# ╞══════════════════╪════════════════════╡
# │ seed             │ None               │
# ├──────────────────┼────────────────────┤
# │ output_dir       │ './YOLOX_outputs'  │
# ├──────────────────┼────────────────────┤
# │ print_interval   │ 20                 │
# ├──────────────────┼────────────────────┤
# │ eval_interval    │ 5                  │
# ├──────────────────┼────────────────────┤
# ...

# %%
# !python3 tools/track.py -f exps/example/mot/yolox_x_ablation.py -c YOLOX_outputs/yolox_x_ablation_ekf/best_ckpt.pth.tar -b 1 -d 1 --fp16 --fuse
# Out:
# 2024-05-02 15:22:24 | INFO     | __main__:154 - Args: Namespace(experiment_name='yolox_x_ablation', name=None, dist_backend='nccl', dist_url=None, batch_size=1, devices=1, local_rank=0, num_machines=1, machine_rank=0, exp_file='exps/example/mot/yolox_x_ablation.py', fp16=True, fuse=True, trt=False, test=False, speed=False, opts=[], ckpt='YOLOX_outputs/yolox_x_ablation_ekf/best_ckpt.pth.tar', conf=0.01, nms=0.7, tsize=None, seed=None, track_thresh=0.6, track_buffer=30, match_thresh=0.9, min_box_area=100, mot20=False)
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 2024-05-02 15:22:25 | INFO     | __main__:164 - Model Summary: Params: 99.00M, Gflops: 793.21
# ...
