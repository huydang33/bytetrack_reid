# %%
# !python3 tools/track.py \
        -f exps/example/mot/yolox_x_ablation.py -c pretrained/bytetrack_ablation.pth.tar \
        -b 1 -d 1 --fp16 --fuse \
        --feat_model_name fastreid \
        --feat_args_cfg "pretrained/fastreid_market1501_bagtrickR50/config.yaml" \
        --feat_model_weights "pretrained/fastreid_market1501_bagtrickR50/model_final.pth" \
        --fusion_type "weight_sum" \
        --match_thresh 0.7
# Out:
# 2024-05-16 09:43:05 | INFO     | __main__:162 - Args: Namespace(experiment_name='yolox_x_ablation', name=None, dist_backend='nccl', dist_url=None, batch_size=1, devices=1, local_rank=0, num_machines=1, machine_rank=0, exp_file='exps/example/mot/yolox_x_ablation.py', fp16=True, fuse=True, trt=False, test=False, speed=False, opts=[], ckpt='pretrained/bytetrack_ablation.pth.tar', conf=0.01, nms=0.7, tsize=None, seed=None, track_thresh=0.6, track_buffer=30, match_thresh=0.7, min_box_area=100, mot20=False, feat_model_name='fastreid', feat_args_cfg='pretrained/fastreid_market1501_bagtrickR50/config.yaml', feat_model_weights='pretrained/fastreid_market1501_bagtrickR50/model_final.pth', reid_weight=0.1, fusion_type='weight_sum')
# /home/huythanhdang/.local/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
# ...

# %%
# !python3 tools/track.py \
        -f exps/example/mot/yolox_x_ablation.py -c pretrained/bytetrack_ablation.pth.tar \
        -b 1 -d 1 --fp16 --fuse \
        --feat_model_name fastreid \
        --feat_args_cfg "pretrained/fastreid_market1501_bagtrickR50/config.yaml" \
        --feat_model_weights "pretrained/fastreid_market1501_bagtrickR50/model_final.pth" \
        --fusion_type "weight_sum" \
        --match_thresh 0.75
# Out:
# 2024-05-16 09:56:48 | INFO     | __main__:162 - Args: Namespace(experiment_name='yolox_x_ablation', name=None, dist_backend='nccl', dist_url=None, batch_size=1, devices=1, local_rank=0, num_machines=1, machine_rank=0, exp_file='exps/example/mot/yolox_x_ablation.py', fp16=True, fuse=True, trt=False, test=False, speed=False, opts=[], ckpt='pretrained/bytetrack_ablation.pth.tar', conf=0.01, nms=0.7, tsize=None, seed=None, track_thresh=0.6, track_buffer=30, match_thresh=0.75, min_box_area=100, mot20=False, feat_model_name='fastreid', feat_args_cfg='pretrained/fastreid_market1501_bagtrickR50/config.yaml', feat_model_weights='pretrained/fastreid_market1501_bagtrickR50/model_final.pth', reid_weight=0.1, fusion_type='weight_sum')
# /home/huythanhdang/.local/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
# ...

# %%
# !python3 tools/track.py \
        -f exps/example/mot/yolox_x_ablation.py -c pretrained/bytetrack_ablation.pth.tar \
        -b 1 -d 1 --fp16 --fuse \
        --feat_model_name fastreid \
        --feat_args_cfg "pretrained/fastreid_market1501_bagtrickR50/config.yaml" \
        --feat_model_weights "pretrained/fastreid_market1501_bagtrickR50/model_final.pth" \
        --fusion_type "weight_sum" \
        --match_thresh 0.8
# Out:
# 2024-05-16 10:10:12 | INFO     | __main__:162 - Args: Namespace(experiment_name='yolox_x_ablation', name=None, dist_backend='nccl', dist_url=None, batch_size=1, devices=1, local_rank=0, num_machines=1, machine_rank=0, exp_file='exps/example/mot/yolox_x_ablation.py', fp16=True, fuse=True, trt=False, test=False, speed=False, opts=[], ckpt='pretrained/bytetrack_ablation.pth.tar', conf=0.01, nms=0.7, tsize=None, seed=None, track_thresh=0.6, track_buffer=30, match_thresh=0.8, min_box_area=100, mot20=False, feat_model_name='fastreid', feat_args_cfg='pretrained/fastreid_market1501_bagtrickR50/config.yaml', feat_model_weights='pretrained/fastreid_market1501_bagtrickR50/model_final.pth', reid_weight=0.1, fusion_type='weight_sum')
# /home/huythanhdang/.local/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
# ...

# %%
# !python3 tools/track.py \
        -f exps/example/mot/yolox_x_ablation.py -c pretrained/bytetrack_ablation.pth.tar \
        -b 1 -d 1 --fp16 --fuse \
        --feat_model_name fastreid \
        --feat_args_cfg "pretrained/fastreid_market1501_bagtrickR50/config.yaml" \
        --feat_model_weights "pretrained/fastreid_market1501_bagtrickR50/model_final.pth" \
        --fusion_type "weight_sum" \
        --match_thresh 0.95
# Out:
# 2024-05-16 11:44:01 | INFO     | __main__:162 - Args: Namespace(experiment_name='yolox_x_ablation', name=None, dist_backend='nccl', dist_url=None, batch_size=1, devices=1, local_rank=0, num_machines=1, machine_rank=0, exp_file='exps/example/mot/yolox_x_ablation.py', fp16=True, fuse=True, trt=False, test=False, speed=False, opts=[], ckpt='pretrained/bytetrack_ablation.pth.tar', conf=0.01, nms=0.7, tsize=None, seed=None, track_thresh=0.6, track_buffer=30, match_thresh=0.95, min_box_area=100, mot20=False, feat_model_name='fastreid', feat_args_cfg='pretrained/fastreid_market1501_bagtrickR50/config.yaml', feat_model_weights='pretrained/fastreid_market1501_bagtrickR50/model_final.pth', reid_weight=0.1, fusion_type='weight_sum')
# /home/huythanhdang/.local/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
# ...

# %%
# !python3 tools/track.py \
        -f exps/example/mot/yolox_x_ablation.py -c pretrained/bytetrack_ablation.pth.tar \
        -b 1 -d 1 --fp16 --fuse \
        --feat_model_name fastreid \
        --feat_args_cfg "pretrained/fastreid_market1501_bagtrickR50/config.yaml" \
        --feat_model_weights "pretrained/fastreid_market1501_bagtrickR50/model_final.pth" \
        --fusion_type "weight_sum" \
        --match_thresh 0.925
# Out:
# 2024-05-16 12:44:04 | INFO     | __main__:162 - Args: Namespace(experiment_name='yolox_x_ablation', name=None, dist_backend='nccl', dist_url=None, batch_size=1, devices=1, local_rank=0, num_machines=1, machine_rank=0, exp_file='exps/example/mot/yolox_x_ablation.py', fp16=True, fuse=True, trt=False, test=False, speed=False, opts=[], ckpt='pretrained/bytetrack_ablation.pth.tar', conf=0.01, nms=0.7, tsize=None, seed=None, track_thresh=0.6, track_buffer=30, match_thresh=0.925, min_box_area=100, mot20=False, feat_model_name='fastreid', feat_args_cfg='pretrained/fastreid_market1501_bagtrickR50/config.yaml', feat_model_weights='pretrained/fastreid_market1501_bagtrickR50/model_final.pth', reid_weight=0.1, fusion_type='weight_sum')
# /home/huythanhdang/.local/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
# ...
